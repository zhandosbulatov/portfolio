# %% [markdown]
# # Exercise 6: Clustering
#
# In this assignment you will experiment with k-means as an image compression algorithm.
#
# ## Read the following instructions carefully:
#
# 1. This jupyter notebook contains all the step by step instructions needed for this exercise.
# 2. Write **efficient vectorized** code whenever possible. Some calculations in this exercise take several minutes when implemented efficiently, and might take much longer otherwise. Unnecessary loops will result in point deduction.
# 3. You are responsible for the correctness of your code and should add as many tests as you see fit. Tests will not be graded nor checked.
# 4. Write your functions in this notebook only. **Do not create Python modules and import them**.
# 5. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/) and [numpy](https://www.numpy.org/devdocs/reference/) only. **Do not import anything else.**
# 6. Your code must run without errors. During the environment setup, you were given a specific version of `numpy` to install (1.15.4). Changes of the configuration we provided are at your own risk. Any code that cannot run will not be graded.
# 7. Write your own code. Cheating will not be tolerated.
# 8. Submission includes this notebook only with the exercise number and your ID as the filename. For example: `hw6_123456789_987654321.ipynb` if you submitted in pairs and `hw6_123456789.ipynb` if you submitted the exercise alone.
# 9. Answers to qualitative questions should be written in **markdown** cells (with $\LaTeX$ support). Answers that will be written in commented code blocks will not be checked.
#
# ## Color image quantization
#
# Color image quantization is the process of transforming an image so that it can be represented with a small subset of colors; a subset smaller than the image's original palette size. Image quantization is a form of lossy data compression since the number of bits used for the palette is reduced. During this compression some data is lost and therefore we must use a careful algorithm that will minimize the perceived difference between the original image and its quantized counterpart. Other than compression, image quantization plays an important role in image recognition algorithms.
#
# When representing images in true color, each pixel is represented by 3 RGB components and each one of the 3 RGB components is represented by 8 bits and can take a value from 0 to 255. This means that in true color representation one can use 2^24≈16 Million different colors. In this exercise we will perform image quantization from images given in true color into 256, 16 or even less colors.
#
# There are many algorithms for quantization. In this exercise, you are going to use K-means in color space to achieve quantization. The color (a point in RGB space) assigned to each pixel is the color of the centroid of the cluster.
#
# To summarize, every pixel in the image is a point in the three dimensional RGB space. We want to cluster these points into k clusters and then replace each pixel by the centroid of the cluster to which it was assigned to obtain the compressed image.
#
# You might need to install skimage using `conda install -c conda-forge scikit-image`.
#
# Also, note that `numpy.power()` is a slow function! https://stackoverflow.com/questions/25254541/why-is-numpy-power-60x-slower-than-in-lining

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
# make matplotlib figures appear inline in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (14.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
# load the image and confirm skimage is imported properly.
image = io.imread('data/small_duck.jpg')
io.imshow(image)
io.show()
print(image.shape)
# Out:
# (564, 1200, 3)

# %% [markdown]
# This single image has over 2 million values. Make sure your code is vectorized and efficient!

# %%
# save the dimensions of the image and reshape it for easier manipulation
rows = image.shape[0]
cols = image.shape[1]
image = image.reshape(image.shape[0]*image.shape[1],3)
print(image.shape)
# Out:
# (676800, 3)

# %% [markdown]
# ## Random centroids (15 points)
#
# Each centroid is a point in RGB space (color) in the image. This function should uniformly pick `k` centroids from the dataset.
#
# Input: a single image of shape `(num_instances, 3)` and `k`, the number of centroids. Notice we are flattening the image to a two dimentional array.
# Output: Randomly chosen centroids of shape `(k,3)`.

# %%
def get_random_centroids(X, k):
    centroids = []
    ###########################################################################
    # TODO: Implement the function.                                           #
    ###########################################################################
    indeces = np.random.permutation(X.shape[0])
    centroids = X[indeces[:k]]
    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################
    return centroids

# %%
k = 7 
centroids = get_random_centroids(image, k)

# %% [markdown]
# ## Distance function (25 points)
#
# The Minkowski distance is a metric which can be considered as a generalization of the Euclidean and Manhattan distances.
#
# The Minkoski distance of order $p$ between two points: $\vec{x}=(x_1, ..., x_n)$ and $\vec{y}=(y_1, ..., y_n)$ is:
# $$D(\vec{x},\vec{y}) = (\sum_{i=1}^n \mid x_i - y_i \mid ^p)^{\frac{1}{p}}$$
#
# Implement the function `lp_distance` (=Minkoski distance).
#
# Inputs:
# * a single image of shape `(num_instances, 3)`
# * the centroids `(k, 3)`
# * the distance parameter p
#
# output: array of shape `(k, num_instances)` thats holds the distances of all points in RGB space from all centroids

# %%
def lp_distance(X, centroids, p=2):
    distances = []
    ###########################################################################
    # TODO: Implement the function.                                           #
    ###########################################################################
    k = centroids.shape[0]
    n = X.shape[0]
    instances = np.array(np.tile(X, k).reshape(n, k, 3), dtype=np.int64)
    centrs = np.array(np.vstack([centroids.reshape(1, k, 3)]*n), dtype=np.int64)
    distances = np.transpose(np.power(np.sum(np.power(np.abs(np.subtract(instances, centrs)), p), axis=2), (1/p)))
    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################
    return distances

# %%
distances = lp_distance(image, centroids, 5)

# %% [markdown]
# ## Kmeans algorithm (40 points)
#
# Calculate the locally optimal centroids as learned in class. At each iteration, assign every RGB point to the closest centroids and calculate new centroids by averaging the points that were assigned to every centroid. This function stops,
# when no improvement was made or once max_iter iterations passed.
#
# A reasonable implementation runs on a Core i7 CPU in less than a minute with `k=16`.

# %%
def kmeans(func, X, k, p ,max_iter=100):
    """
    Inputs:
    - X: a single image of shape (num_features, 3).
    - k: number of centroids.
    - p: the parameter governing the distance measure.
    - max_iter: the maximum number of iterations to perform.
    Outpust:
    - The calculated centroids
    - The final assignment of all RGB points to the closest centroids
    """
    classes = []
    centroids = []
    ###########################################################################
    # TODO: Implement the function.                                           #
    ###########################################################################
    centroids = get_random_centroids(X, k)
    for i in range(max_iter):
        old_centroids = centroids
        distances = lp_distance(X, old_centroids, p)
        labels = np.argmin(distances, axis=0)
        centroids = np.zeros((k, X.shape[1]))

        for j in range(k):
            centroids[j, :] = func(X[labels == j, :], axis=0)
        
        if np.all(old_centroids==centroids):
            break
    inertia = np.sum(np.amin(lp_distance(X, centroids, 2), axis=0))
    classes = labels
    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################
    return centroids, classes, inertia

# %%
centroids, classes, inertia = kmeans(np.mean, image, k=4, p=1, max_iter=100)

# %% [markdown]
# We obtained the locally optimal centroids (colors) from our image. To reconstruct the compressed image, we need to specify the color for each pixel that our algorithm associated with some centroid. The following cell does that for you.

# %%
classes = classes.reshape(rows,cols) 
compressed_image = np.zeros((classes.shape[0],classes.shape[1],3),dtype=np.uint8 )
for i in range(classes.shape[0]):
    for j in range(classes.shape[1]):
            compressed_image[i,j,:] = centroids[classes[i,j],:]
io.imshow(compressed_image)
io.show()

# %% [markdown]
# ## Hyper parameter tuning (20 points)
#
# Run the algorithm for each of the following values for `p = [1,2,3,4,5]` . Test multiple values for `k=[4,8,16]` using two different cluster calculation criteria: the mean and the median of the cluser. For each test, calculate the intertia and visualize it using graphs. Explain your results.

# %%
p_list = [1,2,3,4,5]
k_list = [4,8,16]
inertia_arr1 = []
inertia_arr2 = []
for p in p_list:
    for k in k_list:
        centroids_mean, classes_mean, inertia_mean = kmeans(np.mean, image, k=k, p=p, max_iter=100)
        inertia_arr1.append(inertia_mean)
        print("K-means with p={} and k={} has finished running. Inertia={}\n".format(p, k, inertia_mean))
        centroids_median, classes_median, inertia_median = kmeans(np.median, image, k=k, p=p, max_iter=100)
        inertia_arr2.append(inertia_median)
        print("K-medians with p={} and k={} has finished running. Inertia={}\n".format(p, k, inertia_median))
print(inertia_arr1, '\n', inertia_arr2)
# Out:
# K-means with p=1 and k=4 has finished running. Inertia=26705891.070682425
#
# K-medians with p=1 and k=4 has finished running. Inertia=25787961.659697942
#
# K-means with p=1 and k=8 has finished running. Inertia=18343879.6962862
#
# K-medians with p=1 and k=8 has finished running. Inertia=18412004.679692227
#
# K-means with p=1 and k=16 has finished running. Inertia=12834097.680107208
#
# K-medians with p=1 and k=16 has finished running. Inertia=12601097.428623533
#
# K-means with p=2 and k=4 has finished running. Inertia=26478322.92965706
#
# K-medians with p=2 and k=4 has finished running. Inertia=25635145.623803087
#
# K-means with p=2 and k=8 has finished running. Inertia=19200592.195704766
#
# K-medians with p=2 and k=8 has finished running. Inertia=19333183.355683394
#
# K-means with p=2 and k=16 has finished running. Inertia=12620574.3943018
#
# K-medians with p=2 and k=16 has finished running. Inertia=12463767.05526074
#
# K-means with p=3 and k=4 has finished running. Inertia=26488210.45024222
#
# K-medians with p=3 and k=4 has finished running. Inertia=25680959.415068716
#
# K-means with p=3 and k=8 has finished running. Inertia=18339589.458932873
#
# K-medians with p=3 and k=8 has finished running. Inertia=18324133.737692513
#
# K-means with p=3 and k=16 has finished running. Inertia=12574967.764553204
#
# K-medians with p=3 and k=16 has finished running. Inertia=12447591.754378065
#
# K-means with p=4 and k=4 has finished running. Inertia=26529966.21782581
#
# K-medians with p=4 and k=4 has finished running. Inertia=25650910.078176253
#
# K-means with p=4 and k=8 has finished running. Inertia=18448728.501866642
#
# K-medians with p=4 and k=8 has finished running. Inertia=18790357.67199241
#
# K-means with p=4 and k=16 has finished running. Inertia=12566234.148991782
#
# K-medians with p=4 and k=16 has finished running. Inertia=12547523.614716334
#
# K-means with p=5 and k=4 has finished running. Inertia=26547458.48400907
#
# K-medians with p=5 and k=4 has finished running. Inertia=26057816.232247412
#
# K-means with p=5 and k=8 has finished running. Inertia=18933667.924902435
#
# K-medians with p=5 and k=8 has finished running. Inertia=18367478.717072755
#
# K-means with p=5 and k=16 has finished running. Inertia=12611771.358806137
#
# K-medians with p=5 and k=16 has finished running. Inertia=12496419.652897388
#
# [26705891.070682425, 18343879.6962862, 12834097.680107208, 26478322.92965706, 19200592.195704766, 12620574.3943018, 26488210.45024222, 18339589.458932873, 12574967.764553204, 26529966.21782581, 18448728.501866642, 12566234.148991782, 26547458.48400907, 18933667.924902435, 12611771.358806137]
#  [25787961.659697942, 18412004.679692227, 12601097.428623533, 25635145.623803087, 19333183.355683394, 12463767.05526074, 25680959.415068716, 18324133.737692513, 12447591.754378065, 25650910.078176253, 18790357.67199241, 12547523.614716334, 26057816.232247412, 18367478.717072755, 12496419.652897388]

# %%
plt.figure(1)
plt.xlabel('k')
plt.ylabel('inertia')
plt.title('p=1')
plt.plot(k_list, inertia_arr1[:3], 'r')
plt.plot(k_list, inertia_arr2[:3], 'b')

# %%
plt.figure(2)
plt.xlabel('k')
plt.ylabel('inertia')
plt.title('p=2')
plt.plot(k_list, inertia_arr1[3:6], 'r')
plt.plot(k_list, inertia_arr2[3:6], 'b')

# %%
plt.figure(3)
plt.xlabel('k')
plt.ylabel('inertia')
plt.title('p=3')
plt.plot(k_list, inertia_arr1[6:9], 'r')
plt.plot(k_list, inertia_arr2[6:9], 'b')

# %%
plt.figure(4)
plt.xlabel('k')
plt.ylabel('inertia')
plt.title('p=4')
plt.plot(k_list, inertia_arr1[9:12], 'r')
plt.plot(k_list, inertia_arr2[9:12], 'b')

# %%
plt.figure(5)
plt.xlabel('k')
plt.ylabel('inertia')
plt.title('p=5')
plt.plot(k_list, inertia_arr1[12:15], 'r')
plt.plot(k_list, inertia_arr2[12:15], 'b')
